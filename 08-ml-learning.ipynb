# %% [markdown]
# # 8. Machine learning

# %% [markdown]
# ## Setup and imports

# %%
from functions import *

# %%
df = load_data()
df = df.sort_index()
df = df.asfreq("h")
df = df.interpolate(method="time", limit_direction="both")
df = df.reset_index()  # siin on juba veerg nimega 'timestamp', ei ole vaja rename

df["hour"] = df["timestamp"].dt.hour
df["weekday"] = df["timestamp"].dt.dayofweek
df["is_weekend"] = (df["weekday"] >= 5).astype(int)
df["hour_sin"] = np.sin(2 * np.pi * df["hour"] / 24)
df["hour_cos"] = np.cos(2 * np.pi * df["hour"] / 24)
df["cooling_degree"] = np.clip(df["temperature"] - 18, 0, None)
df["heating_degree"] = np.clip(18 - df["temperature"], 0, None)

selected_features = [
    "timestamp", "demand", "hour_sin", "hour_cos", "is_weekend",
    "cooling_degree", "heating_degree", "temperature", "pressure (hPa)",
    "cloud_cover (%)", "wind_speed_10m (km/h)", "shortwave_radiation (W/m²)",
    "direct_radiation (W/m²)", "diffuse_radiation (W/m²)",
    "direct_normal_irradiance (W/m²)", "price"
]

df = df[selected_features].round(5)

# %%
show_table_info(df, "Training data")
# Out:
# TRAINING DATA SUMMARY
# Shape: 8,760 rows × 16 columns
# Time span: 2013-07-01 00:00:00+00:00 -> 2014-06-30 23:00:00+00:00
#
#                          Column    Type   NA %
#                          demand float64  0.00%
#                        hour_sin float64  0.00%
#                        hour_cos float64  0.00%
#                      is_weekend   int64  0.00%
#                  cooling_degree float64  0.00%
#                  heating_degree float64  0.00%
#                     temperature float64  0.00%
#                  pressure (hPa) float64  0.00%
#                 cloud_cover (%) float64  0.00%
#           wind_speed_10m (km/h) float64  0.00%
#      shortwave_radiation (W/m²) float64  0.00%
#         direct_radiation (W/m²) float64  0.00%
#        diffuse_radiation (W/m²) float64  0.00%
# direct_normal_irradiance (W/m²) float64  0.00%
#                           price float64  0.00%
#                              Column     Type    NA %
# 0                            demand  float64   0.00%
# 1                          hour_sin  float64   0.00%
# 2                          hour_cos  float64   0.00%
# 3                        is_weekend    int64   0.00%
# 4                    cooling_degree  float64   0.00%
# 5                    heating_degree  float64   0.00%
# 6                       temperature  float64   0.00%
# 7                    pressure (hPa)  float64   0.00%
# 8                   cloud_cover (%)  float64   0.00%
# 9             wind_speed_10m (km/h)  float64   0.00%
# 10       shortwave_radiation (W/m²)  float64   0.00%
# 11          direct_radiation (W/m²)  float64   0.00%
# 12         diffuse_radiation (W/m²)  float64   0.00%
# 13  direct_normal_irradiance (W/m²)  float64   0.00%
# 14                            price  float64   0.00%

# %%
VALIDATION_DAYS = 7
FORECAST_HORIZON = 24
cutoff = df["timestamp"].max() - pd.Timedelta(days=VALIDATION_DAYS)

train = df[df["timestamp"] < cutoff].copy()
test = df[df["timestamp"] >= cutoff].copy()

X_train = train.drop(columns=["demand", "timestamp"])
y_train = train["demand"]
X_test = test.drop(columns=["demand", "timestamp"])
y_test = test["demand"]

# %% [markdown]
# ## 1. Train XGBoost forecasting model

# %%
model, eval_history = train_xgboost(X_train, y_train, X_test, y_test)
# Out:
# [0]	validation_0-rmse:0.37109	validation_1-rmse:0.36378
# [1]	validation_0-rmse:0.36689	validation_1-rmse:0.36093
# [2]	validation_0-rmse:0.36401	validation_1-rmse:0.36053
# [3]	validation_0-rmse:0.36130	validation_1-rmse:0.35909
# [4]	validation_0-rmse:0.35781	validation_1-rmse:0.35722
# [5]	validation_0-rmse:0.35611	validation_1-rmse:0.35614
# [6]	validation_0-rmse:0.35295	validation_1-rmse:0.35409
# [7]	validation_0-rmse:0.34996	validation_1-rmse:0.35231
# [8]	validation_0-rmse:0.34789	validation_1-rmse:0.35185
# [9]	validation_0-rmse:0.34510	validation_1-rmse:0.35040
# [10]	validation_0-rmse:0.34260	validation_1-rmse:0.34900
# [11]	validation_0-rmse:0.34028	validation_1-rmse:0.34795
# [12]	validation_0-rmse:0.33833	validation_1-rmse:0.34682
# [13]	validation_0-rmse:0.33620	validation_1-rmse:0.34647
# [14]	validation_0-rmse:0.33444	validation_1-rmse:0.34620
# [15]	validation_0-rmse:0.33300	validation_1-rmse:0.34563
# [16]	validation_0-rmse:0.33129	validation_1-rmse:0.34484
# [17]	validation_0-rmse:0.32944	validation_1-rmse:0.34371
# [18]	validation_0-rmse:0.32784	validation_1-rmse:0.34323
# [19]	validation_0-rmse:0.32663	validation_1-rmse:0.34287
# [20]	validation_0-rmse:0.32529	validation_1-rmse:0.34251
# [21]	validation_0-rmse:0.32375	validation_1-rmse:0.34139
# [22]	validation_0-rmse:0.32289	validation_1-rmse:0.34087
# [23]	validation_0-rmse:0.32145	validation_1-rmse:0.34093
# [24]	validation_0-rmse:0.32028	validation_1-rmse:0.34027
# [25]	validation_0-rmse:0.31926	validation_1-rmse:0.33963
# [26]	validation_0-rmse:0.31825	validation_1-rmse:0.33904
# [27]	validation_0-rmse:0.31701	validation_1-rmse:0.33888
# [28]	validation_0-rmse:0.31603	validation_1-rmse:0.33884
# [29]	validation_0-rmse:0.31496	validation_1-rmse:0.33862
# [30]	validation_0-rmse:0.31385	validation_1-rmse:0.33839
# [31]	validation_0-rmse:0.31288	validation_1-rmse:0.33816
# [32]	validation_0-rmse:0.31173	validation_1-rmse:0.33797
# [33]	validation_0-rmse:0.31114	validation_1-rmse:0.33795
# [34]	validation_0-rmse:0.31018	validation_1-rmse:0.33749
# [35]	validation_0-rmse:0.30950	validation_1-rmse:0.33772
# [36]	validation_0-rmse:0.30853	validation_1-rmse:0.33811
# [37]	validation_0-rmse:0.30785	validation_1-rmse:0.33823
# [38]	validation_0-rmse:0.30712	validation_1-rmse:0.33800
# [39]	validation_0-rmse:0.30613	validation_1-rmse:0.33777
# [40]	validation_0-rmse:0.30550	validation_1-rmse:0.33770
# [41]	validation_0-rmse:0.30477	validation_1-rmse:0.33765
# [42]	validation_0-rmse:0.30374	validation_1-rmse:0.33751
# [43]	validation_0-rmse:0.30299	validation_1-rmse:0.33685
# [44]	validation_0-rmse:0.30244	validation_1-rmse:0.33699
# [45]	validation_0-rmse:0.30185	validation_1-rmse:0.33692
# [46]	validation_0-rmse:0.30110	validation_1-rmse:0.33547
# [47]	validation_0-rmse:0.30045	validation_1-rmse:0.33574
# [48]	validation_0-rmse:0.29979	validation_1-rmse:0.33528
# [49]	validation_0-rmse:0.29888	validation_1-rmse:0.33507
# [292]	validation_0-rmse:0.20584	validation_1-rmse:0.34604
# [293]	validation_0-rmse:0.20561	validation_1-rmse:0.34614
# [294]	validation_0-rmse:0.20517	validation_1-rmse:0.34621
# [295]	validation_0-rmse:0.20496	validation_1-rmse:0.34643
# [296]	validation_0-rmse:0.20472	validation_1-rmse:0.34665
# [297]	validation_0-rmse:0.20454	validation_1-rmse:0.34647
# [298]	validation_0-rmse:0.20441	validation_1-rmse:0.34647
# [299]	validation_0-rmse:0.20394	validation_1-rmse:0.34647
# [300]	validation_0-rmse:0.20381	validation_1-rmse:0.34664
# [301]	validation_0-rmse:0.20364	validation_1-rmse:0.34663
# [302]	validation_0-rmse:0.20329	validation_1-rmse:0.34661
# [303]	validation_0-rmse:0.20300	validation_1-rmse:0.34660
# [304]	validation_0-rmse:0.20262	validation_1-rmse:0.34661
# [305]	validation_0-rmse:0.20245	validation_1-rmse:0.34661
# [306]	validation_0-rmse:0.20202	validation_1-rmse:0.34656
# [307]	validation_0-rmse:0.20183	validation_1-rmse:0.34650
# [308]	validation_0-rmse:0.20149	validation_1-rmse:0.34647
# [309]	validation_0-rmse:0.20107	validation_1-rmse:0.34648
# [310]	validation_0-rmse:0.20094	validation_1-rmse:0.34663
# [311]	validation_0-rmse:0.20081	validation_1-rmse:0.34650
# [312]	validation_0-rmse:0.20061	validation_1-rmse:0.34653
# [313]	validation_0-rmse:0.20040	validation_1-rmse:0.34650
# [314]	validation_0-rmse:0.20015	validation_1-rmse:0.34674
# [315]	validation_0-rmse:0.19992	validation_1-rmse:0.34707
# [316]	validation_0-rmse:0.19970	validation_1-rmse:0.34708
# [317]	validation_0-rmse:0.19940	validation_1-rmse:0.34746
# [318]	validation_0-rmse:0.19913	validation_1-rmse:0.34753
# [319]	validation_0-rmse:0.19887	validation_1-rmse:0.34748
# [320]	validation_0-rmse:0.19877	validation_1-rmse:0.34726
# [321]	validation_0-rmse:0.19851	validation_1-rmse:0.34718
# [322]	validation_0-rmse:0.19817	validation_1-rmse:0.34731
# [323]	validation_0-rmse:0.19798	validation_1-rmse:0.34742
# [324]	validation_0-rmse:0.19775	validation_1-rmse:0.34737
# [325]	validation_0-rmse:0.19751	validation_1-rmse:0.34752
# [326]	validation_0-rmse:0.19718	validation_1-rmse:0.34755
# [327]	validation_0-rmse:0.19673	validation_1-rmse:0.34770
# [328]	validation_0-rmse:0.19651	validation_1-rmse:0.34805
# [329]	validation_0-rmse:0.19626	validation_1-rmse:0.34809
# [330]	validation_0-rmse:0.19608	validation_1-rmse:0.34809
# [331]	validation_0-rmse:0.19582	validation_1-rmse:0.34813
# [332]	validation_0-rmse:0.19565	validation_1-rmse:0.34857
# [333]	validation_0-rmse:0.19544	validation_1-rmse:0.34867
# [334]	validation_0-rmse:0.19538	validation_1-rmse:0.34861
# [335]	validation_0-rmse:0.19512	validation_1-rmse:0.34865
# [336]	validation_0-rmse:0.19495	validation_1-rmse:0.34866
# [337]	validation_0-rmse:0.19465	validation_1-rmse:0.34899
# [338]	validation_0-rmse:0.19440	validation_1-rmse:0.34880
# [339]	validation_0-rmse:0.19417	validation_1-rmse:0.34919
# [340]	validation_0-rmse:0.19399	validation_1-rmse:0.34925
# [341]	validation_0-rmse:0.19375	validation_1-rmse:0.34938
# [342]	validation_0-rmse:0.19350	validation_1-rmse:0.34940
# [343]	validation_0-rmse:0.19316	validation_1-rmse:0.34930
# [344]	validation_0-rmse:0.19265	validation_1-rmse:0.34929
# [345]	validation_0-rmse:0.19239	validation_1-rmse:0.34928
# [346]	validation_0-rmse:0.19218	validation_1-rmse:0.34923
# [347]	validation_0-rmse:0.19200	validation_1-rmse:0.34923
# [348]	validation_0-rmse:0.19187	validation_1-rmse:0.34958
# [349]	validation_0-rmse:0.19155	validation_1-rmse:0.34939
# [350]	validation_0-rmse:0.19146	validation_1-rmse:0.34931
# [351]	validation_0-rmse:0.19116	validation_1-rmse:0.34963
# [352]	validation_0-rmse:0.19096	validation_1-rmse:0.34981
# [353]	validation_0-rmse:0.19067	validation_1-rmse:0.34985
# [354]	validation_0-rmse:0.19036	validation_1-rmse:0.35001
# [355]	validation_0-rmse:0.19026	validation_1-rmse:0.35001
# [356]	validation_0-rmse:0.18992	validation_1-rmse:0.34999
# [357]	validation_0-rmse:0.18963	validation_1-rmse:0.34997
# [358]	validation_0-rmse:0.18951	validation_1-rmse:0.34995
# [359]	validation_0-rmse:0.18929	validation_1-rmse:0.34999
# [360]	validation_0-rmse:0.18896	validation_1-rmse:0.35006
# [361]	validation_0-rmse:0.18878	validation_1-rmse:0.35003
# [362]	validation_0-rmse:0.18857	validation_1-rmse:0.35005
# [363]	validation_0-rmse:0.18826	validation_1-rmse:0.34997
# [364]	validation_0-rmse:0.18796	validation_1-rmse:0.34999
# [365]	validation_0-rmse:0.18768	validation_1-rmse:0.35003
# [366]	validation_0-rmse:0.18740	validation_1-rmse:0.35005
# [367]	validation_0-rmse:0.18726	validation_1-rmse:0.35007
# [368]	validation_0-rmse:0.18700	validation_1-rmse:0.35021
# [369]	validation_0-rmse:0.18693	validation_1-rmse:0.35039
# [370]	validation_0-rmse:0.18683	validation_1-rmse:0.35042
# [371]	validation_0-rmse:0.18652	validation_1-rmse:0.35032
# [372]	validation_0-rmse:0.18644	validation_1-rmse:0.35033
# [373]	validation_0-rmse:0.18611	validation_1-rmse:0.35038
# [374]	validation_0-rmse:0.18593	validation_1-rmse:0.35038
# [375]	validation_0-rmse:0.18580	validation_1-rmse:0.35042
# [376]	validation_0-rmse:0.18553	validation_1-rmse:0.35053
# [377]	validation_0-rmse:0.18529	validation_1-rmse:0.35057
# [378]	validation_0-rmse:0.18514	validation_1-rmse:0.35067
# [379]	validation_0-rmse:0.18499	validation_1-rmse:0.35103
# [380]	validation_0-rmse:0.18479	validation_1-rmse:0.35105
# [381]	validation_0-rmse:0.18441	validation_1-rmse:0.35112
# [382]	validation_0-rmse:0.18399	validation_1-rmse:0.35114
# [383]	validation_0-rmse:0.18380	validation_1-rmse:0.35114
# [384]	validation_0-rmse:0.18338	validation_1-rmse:0.35121
# [385]	validation_0-rmse:0.18312	validation_1-rmse:0.35118
# [386]	validation_0-rmse:0.18280	validation_1-rmse:0.35116
# [387]	validation_0-rmse:0.18253	validation_1-rmse:0.35119
# [388]	validation_0-rmse:0.18236	validation_1-rmse:0.35118
# [389]	validation_0-rmse:0.18213	validation_1-rmse:0.35128
# [390]	validation_0-rmse:0.18190	validation_1-rmse:0.35151
# [391]	validation_0-rmse:0.18152	validation_1-rmse:0.35141
# [392]	validation_0-rmse:0.18134	validation_1-rmse:0.35125
# [393]	validation_0-rmse:0.18119	validation_1-rmse:0.35155
# [394]	validation_0-rmse:0.18110	validation_1-rmse:0.35162
# [395]	validation_0-rmse:0.18090	validation_1-rmse:0.35150
# [396]	validation_0-rmse:0.18067	validation_1-rmse:0.35158
# [397]	validation_0-rmse:0.18061	validation_1-rmse:0.35160
# [398]	validation_0-rmse:0.18031	validation_1-rmse:0.35164
# [399]	validation_0-rmse:0.18006	validation_1-rmse:0.35180
# [400]	validation_0-rmse:0.17992	validation_1-rmse:0.35165
# [401]	validation_0-rmse:0.17961	validation_1-rmse:0.35177
# [402]	validation_0-rmse:0.17950	validation_1-rmse:0.35152
# [403]	validation_0-rmse:0.17937	validation_1-rmse:0.35174
# [404]	validation_0-rmse:0.17922	validation_1-rmse:0.35182
# [405]	validation_0-rmse:0.17909	validation_1-rmse:0.35178
# [406]	validation_0-rmse:0.17884	validation_1-rmse:0.35157
# [407]	validation_0-rmse:0.17862	validation_1-rmse:0.35161
# [408]	validation_0-rmse:0.17830	validation_1-rmse:0.35163
# [409]	validation_0-rmse:0.17817	validation_1-rmse:0.35152
# [410]	validation_0-rmse:0.17799	validation_1-rmse:0.35147
# [411]	validation_0-rmse:0.17769	validation_1-rmse:0.35118
# [412]	validation_0-rmse:0.17749	validation_1-rmse:0.35122
# [413]	validation_0-rmse:0.17730	validation_1-rmse:0.35124
# [414]	validation_0-rmse:0.17710	validation_1-rmse:0.35118
# [415]	validation_0-rmse:0.17697	validation_1-rmse:0.35119
# [416]	validation_0-rmse:0.17669	validation_1-rmse:0.35125
# [417]	validation_0-rmse:0.17653	validation_1-rmse:0.35101
# [418]	validation_0-rmse:0.17628	validation_1-rmse:0.35107
# [419]	validation_0-rmse:0.17601	validation_1-rmse:0.35102
# [420]	validation_0-rmse:0.17578	validation_1-rmse:0.35106
# [421]	validation_0-rmse:0.17564	validation_1-rmse:0.35113
# [422]	validation_0-rmse:0.17544	validation_1-rmse:0.35114
# [423]	validation_0-rmse:0.17521	validation_1-rmse:0.35129
# [424]	validation_0-rmse:0.17498	validation_1-rmse:0.35127
# [425]	validation_0-rmse:0.17487	validation_1-rmse:0.35159
# [426]	validation_0-rmse:0.17471	validation_1-rmse:0.35139
# [427]	validation_0-rmse:0.17448	validation_1-rmse:0.35134
# [428]	validation_0-rmse:0.17442	validation_1-rmse:0.35130
# [429]	validation_0-rmse:0.17426	validation_1-rmse:0.35130
# [430]	validation_0-rmse:0.17411	validation_1-rmse:0.35113
# [431]	validation_0-rmse:0.17383	validation_1-rmse:0.35162
# [432]	validation_0-rmse:0.17373	validation_1-rmse:0.35126
# [433]	validation_0-rmse:0.17341	validation_1-rmse:0.35128
# [434]	validation_0-rmse:0.17318	validation_1-rmse:0.35130
# [435]	validation_0-rmse:0.17281	validation_1-rmse:0.35128
# [436]	validation_0-rmse:0.17272	validation_1-rmse:0.35135
# [437]	validation_0-rmse:0.17246	validation_1-rmse:0.35153
# [438]	validation_0-rmse:0.17229	validation_1-rmse:0.35148
# [439]	validation_0-rmse:0.17211	validation_1-rmse:0.35152
# [440]	validation_0-rmse:0.17191	validation_1-rmse:0.35157
# [441]	validation_0-rmse:0.17175	validation_1-rmse:0.35153
# [442]	validation_0-rmse:0.17167	validation_1-rmse:0.35154
# [443]	validation_0-rmse:0.17148	validation_1-rmse:0.35163
# [444]	validation_0-rmse:0.17130	validation_1-rmse:0.35189
# [445]	validation_0-rmse:0.17124	validation_1-rmse:0.35197
# [446]	validation_0-rmse:0.17090	validation_1-rmse:0.35193
# [447]	validation_0-rmse:0.17081	validation_1-rmse:0.35208
# [448]	validation_0-rmse:0.17056	validation_1-rmse:0.35209
# [449]	validation_0-rmse:0.17037	validation_1-rmse:0.35205
# [450]	validation_0-rmse:0.17020	validation_1-rmse:0.35204
# [451]	validation_0-rmse:0.17000	validation_1-rmse:0.35223
# [452]	validation_0-rmse:0.16984	validation_1-rmse:0.35235
# [453]	validation_0-rmse:0.16955	validation_1-rmse:0.35229
# [454]	validation_0-rmse:0.16934	validation_1-rmse:0.35229
# [455]	validation_0-rmse:0.16915	validation_1-rmse:0.35245
# [456]	validation_0-rmse:0.16895	validation_1-rmse:0.35249
# [457]	validation_0-rmse:0.16887	validation_1-rmse:0.35253
# [458]	validation_0-rmse:0.16883	validation_1-rmse:0.35255
# [459]	validation_0-rmse:0.16851	validation_1-rmse:0.35255
# [460]	validation_0-rmse:0.16835	validation_1-rmse:0.35273
# [461]	validation_0-rmse:0.16823	validation_1-rmse:0.35264
# [462]	validation_0-rmse:0.16811	validation_1-rmse:0.35257
# [463]	validation_0-rmse:0.16789	validation_1-rmse:0.35235
# [464]	validation_0-rmse:0.16759	validation_1-rmse:0.35244
# [465]	validation_0-rmse:0.16746	validation_1-rmse:0.35247
# [466]	validation_0-rmse:0.16717	validation_1-rmse:0.35248
# [467]	validation_0-rmse:0.16691	validation_1-rmse:0.35248
# [468]	validation_0-rmse:0.16671	validation_1-rmse:0.35273
# [469]	validation_0-rmse:0.16665	validation_1-rmse:0.35270
# [470]	validation_0-rmse:0.16643	validation_1-rmse:0.35259
# [471]	validation_0-rmse:0.16625	validation_1-rmse:0.35279
# [472]	validation_0-rmse:0.16604	validation_1-rmse:0.35278
# [473]	validation_0-rmse:0.16595	validation_1-rmse:0.35289
# [474]	validation_0-rmse:0.16568	validation_1-rmse:0.35294
# [475]	validation_0-rmse:0.16540	validation_1-rmse:0.35318
# [476]	validation_0-rmse:0.16519	validation_1-rmse:0.35291
# [477]	validation_0-rmse:0.16503	validation_1-rmse:0.35307
# [478]	validation_0-rmse:0.16486	validation_1-rmse:0.35308
# [479]	validation_0-rmse:0.16477	validation_1-rmse:0.35308
# [480]	validation_0-rmse:0.16466	validation_1-rmse:0.35318
# [481]	validation_0-rmse:0.16446	validation_1-rmse:0.35334
# [482]	validation_0-rmse:0.16430	validation_1-rmse:0.35335
# [483]	validation_0-rmse:0.16408	validation_1-rmse:0.35337
# [484]	validation_0-rmse:0.16389	validation_1-rmse:0.35345
# [485]	validation_0-rmse:0.16369	validation_1-rmse:0.35344
# [486]	validation_0-rmse:0.16350	validation_1-rmse:0.35346
# [487]	validation_0-rmse:0.16327	validation_1-rmse:0.35352
# [488]	validation_0-rmse:0.16311	validation_1-rmse:0.35363
# [489]	validation_0-rmse:0.16302	validation_1-rmse:0.35363
# [490]	validation_0-rmse:0.16285	validation_1-rmse:0.35365
# [491]	validation_0-rmse:0.16260	validation_1-rmse:0.35363
# [492]	validation_0-rmse:0.16240	validation_1-rmse:0.35362
# [493]	validation_0-rmse:0.16221	validation_1-rmse:0.35361
# [494]	validation_0-rmse:0.16206	validation_1-rmse:0.35368
# [495]	validation_0-rmse:0.16168	validation_1-rmse:0.35351
# [496]	validation_0-rmse:0.16135	validation_1-rmse:0.35351
# [497]	validation_0-rmse:0.16115	validation_1-rmse:0.35359
# [498]	validation_0-rmse:0.16101	validation_1-rmse:0.35358
# [499]	validation_0-rmse:0.16074	validation_1-rmse:0.35351

# %% [markdown]
# ## Single-day validation

# %%
# First 24h
test_day = test.head(FORECAST_HORIZON)
X_test_day = test_day.drop(columns=["demand", "timestamp"])
y_test_day = test_day["demand"]
y_pred_day = model.predict(X_test_day)

metrics_day = evaluate_forecast(y_test_day.values, y_pred_day)
metrics_day_df = pd.DataFrame([{**metrics_day, "model": "XGBoost", "validation": "Single 24h"}])

# %% [markdown]
# ## Week validation

# %%
y_pred_week = model.predict(X_test)
metrics_week = evaluate_forecast(y_test.values, y_pred_week)
metrics_week_df = pd.DataFrame([{**metrics_week, "model": "XGBoost", "validation": "Week"}])

# %% [markdown]
# ## Summary table for single day and week

# %%
combined_metrics = pd.concat([metrics_day_df, metrics_week_df], ignore_index=True)
combined_metrics.round(5)
# Out:
#        MAE     RMSE    nRMSE     MAPE    model  validation
# 0  0.15238  0.19127  0.16209  0.28818  XGBoost  Single 24h
# 1  0.20718  0.35351  0.16068  0.38457  XGBoost        Week

# %%
fig_day = plot_forecast(test_day["timestamp"], y_test_day, y_pred_day, "XGBoost – 24h", "ex8_fig1_xgb_forecast_day.svg")
fig_week = plot_forecast(test["timestamp"], y_test, y_pred_week, "XGBoost – Week", "ex8_fig2_xgb_forecast_week.svg")
fig_day.show()
fig_week.show()

# %% [markdown]
# ## 2. Table with selected hyperparameters
# These values were chosen to balance accuracy and generalization capability.
# A small learning rate with sufficient estimators allows gradual convergence.
# Moderate depth and subsampling prevent overfitting.
# Regularization (reg_lambda) improves robustness.
# The histogram tree method provides faster computation without major accuracy loss.
#
# | Parameter         | Value | Description |
# |-------------------|--------|-------------|
# | n_estimators      | 500 | A large number ensures model stability with a small learning rate. |
# | learning_rate     | 0.05 | A small step size allows gradual learning and better generalization. |
# | max_depth         | 6 | Moderate depth prevents overfitting while capturing key interactions. |
# | subsample         | 0.8 | Sampling rows improves generalization and reduces variance. |
# | colsample_bytree  | 0.8 | Feature-level sampling helps reduce correlation between trees. |
# | reg_lambda        | 1.0 | L2 regularization adds stability and controls model complexity. |
# | tree_method       | hist | Efficient histogram-based algorithm, faster for large datasets. |
# | objective         | reg:squarederror | Appropriate for continuous-value regression tasks. |
# | eval_metric       | rmse | Root Mean Squared Error used as primary performance metric. |
